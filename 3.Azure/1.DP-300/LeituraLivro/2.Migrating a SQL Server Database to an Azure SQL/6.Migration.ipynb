-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # <mark>Exercise: Migrating a SQL Server Database to Azure SQL Database Using Azure DMS</mark>

-- %% [markdown]
-- # <mark>1) Data Migration Assistant</mark>
--
-- <mark>https://www.microsoft.com/en-us/download/details.aspx?id=53595
-- </mark>
--
-- <mark>
-- </mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # <mark>\## Passo 1</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ## <mark>\## Passo 2)</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- \## Passo 3 )Passar pelas validações
--
--
--
-- ![](attachment:image.png)

-- %% [markdown]
-- ### <mark>https://www.sqlshack.com/overview-of-create-database-statement-in-azure-sql-server/#:~:text=Navigate%20to%20SQL%20databases%20and,and%20service%20objective%20as%20S0.</mark>

-- %%
Create database ControleAereo COLLATE Latin1_General_CI_AS  ( EDITION = 'basic' , MAXSIZE =2GB)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- \## Videos
--
--
--
-- https://www.youtube.com/watch?v=txpeHMJNQPU&t=230s
--
-- https://www.youtube.com/watch?v=xN3UoIRLWxo
--
-- https://www.youtube.com/watch?v=L8YdX2PKPVA
--
-- https://www.youtube.com/watch?v=P\_4EaqVR5PI

-- %% [markdown]
-- # <mark>\## 2) SQL Server Data Tools (SSDT) for Visual Studio</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # <mark>\## 3) SQL Server Management Studio (SSMS)</mark>

-- %% [markdown]
-- # <mark>\## 4) SQLPackage.exe</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # <mark>\## 5) SQL Azure Migration Wizard</mark>
--
-- <mark>: https://github.com/adragoset/SQLAzureMigration
-- </mark>
--
-- <mark>
-- </mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # <mark>\## 6) Azure Database Migration Services</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # <mark>Pagina 109</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # <mark>\## 2)  Localizar o seguinte recurso</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # <mark>\## Passo a passo migração</mark>
--
-- [https://docs.microsoft.com/pt-br/azure/dms/tutorial-sql-server-managed-instance-online-ads?WT.mc\_id=Portal-Microsoft\_Azure\_DMS](https://docs.microsoft.com/pt-br/azure/dms/tutorial-sql-server-managed-instance-online-ads?WT.mc_id=Portal-Microsoft_Azure_DMS)
--
-- https://docs.microsoft.com/pt-br/azure/dms/tutorial-sql-server-to-azure-sql

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # <mark>\## Segunda opção</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # <mark>\## 4) Migrating an On-Premises SQL Server Database to Azure SQL Database</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)
