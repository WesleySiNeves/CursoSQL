# %% [markdown]
# ### <mark><span style="color: rgb(23, 23, 23); font-family: &quot;Segoe UI&quot;, SegoeUI, &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-size: 16px;">The&nbsp;</span> <span style="box-sizing: inherit; outline-color: inherit; font-weight: 600; color: rgb(23, 23, 23); font-family: &quot;Segoe UI&quot;, SegoeUI, &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-size: 16px;">Get-AzNetworkInterface</span> <span style="color: rgb(23, 23, 23); font-family: &quot;Segoe UI&quot;, SegoeUI, &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif; font-size: 16px;">&nbsp;cmdlet gets an Azure network interface or a list of Azure network interfaces in a resource group.</span></mark>

# %%
Connect-AzAccount

# %% [markdown]
# \## Localiza todas as interfaces de redes que não estão marcads com <span style="color: rgb(0, 16, 128); font-family: Consolas, &quot;Courier New&quot;, monospace; font-size: 12px; white-space: pre;">AcceleratedNetworking</span>

# %%
$allInterfaces=  Get-AzNetworkInterface -ResourceGroupName "RgPrd" | Where-Object {$_.EnableAcceleratedNetworking -eq $false}
$allInterfaces
# Out:
# Name                        : dev-daf-1-nic
# ResourceGroupName           : RgPrd
# Location                    : brazilsouth
# Id                          : /subscriptions/b98b628c-0499-4165-bdb4-34c81b728ca4/resourceGroups/RgPrd/providers/Micros
#                               oft.Network/networkInterfaces/dev-daf-1-nic
# Etag                        : W/"1d76129e-cbcf-4116-ab28-279a96b942fd"
# ResourceGuid                : 3c8b2403-2a37-4c35-bc4d-56097ed96522
# ProvisioningState           : Succeeded
# Tags                        :
#                               Name       Value
#                               =========  =====
#                               dev-daf-1
#
# VirtualMachine              : {
#                                 "Id": "/subscriptions/b98b628c-0499-4165-bdb4-34c81b728ca4/resourceGroups/RGPRD/provide
#                               rs/Microsoft.Compute/virtualMachines/dev-daf-1"
#                               }
# IpConfigurations            : [
# ...
