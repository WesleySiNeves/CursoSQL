-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %%
SELECT name, recovery_model_desc FROM sys.databases;
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.062
-- <table><tr><th>name</th><th>recovery_model_desc</th></tr><tr><td>master</td><td>FULL</td></tr><tr><td>AdventureWorksLT</td><td>FULL</td></tr></table>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- <mark>Para o azure temos o Azure Automation ou o Elastcs Jobs</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- <mark>no azure temos o temporal table</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ### <mark>## Unsupported Features</mark>

-- %% [markdown]
-- ![](attachment:image.png)
