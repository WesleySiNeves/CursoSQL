-- %% [markdown]
-- # <mark>Provisioning an Azure SQL Database</mark>

-- %% [markdown]
-- Best Practs nomenclatura
--
-- ## https://docs.microsoft.com/pt-br/azure/cloud-adoption-framework/ready/azure-best-practices/naming-and-tagging

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ## <mark>**## Connecting to and Querying the SQL Database from SQL Server Management Studio**</mark>

-- %% [markdown]
-- ![](attachment:image.png)
