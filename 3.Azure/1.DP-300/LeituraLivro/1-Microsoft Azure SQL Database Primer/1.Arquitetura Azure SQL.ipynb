-- %% [markdown]
-- # <mark>Azure SQL Architecture</mark>

-- %% [markdown]
-- ## https://github.com/TrainingByPackt/Professional-Azure-SQL-Database-Administration-Second-Edition

-- %% [markdown]
-- [Sql Azure Arquitecture](https://www.youtube.com/watch?v=jbXs-EdxuBo)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ## **<mark>\## Camadas</mark>**

-- %% [markdown]
--
--
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ### <mark>**###Azure SQL Database Request Flow**</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # <mark>\## Arquitetura de conexões</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # <mark>\## Politicas de conexões</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # <mark>\## Conectividade do Azure</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)
