-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- # \## Introdução

-- %% [markdown]
-- <mark>Create Database</mark>

-- %% [markdown]
-- ## \## Comandos  DML

-- %% [markdown]
-- ## ![](data:image/png;base64,...)

-- %% [markdown]
-- Se conectar no banco de dados

-- %% [markdown]
-- # \## Criar o banco de dados das Faculdade

-- %% [markdown]
-- # \## Conectar no banco de dados
--
--
--
-- O comando Use Conectar no banco de dasdos

-- %% [markdown]
-- # \## Consultando os Schemas

-- %% [markdown]
-- # \## Consultando as Tabelas

-- %% [markdown]
-- # \## O que são Schemas no Banco de Dados

-- %% [markdown]
-- # <mark>\## Schemas</mark>

-- %% [markdown]
-- # <mark>##Tabelas</mark>

-- %% [markdown]
-- # \# Comandos Alter

-- %% [markdown]
-- ## \## Código

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- **<u>_Escre o que vc quer_</u>**
